# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# %pip show requests
# Out:
# Name: requestsNote: you may need to restart the kernel to use updated packages.
#
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: c:\Users\qwer\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: aext-assistant-server, anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# %pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: c:\Users\qwer\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert
# Note: you may need to restart the kernel to use updated packages.

# %%
# reqeusts, bs4 import
import requests 
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 {requests.__version__}')
print(f'beautifulsoup4 버전 {bs4.__version__}')
# Out:
# requests 버전 2.32.3
# beautifulsoup4 버전 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': '105'
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

#url2 ='https://news.naver.com/section/105'

# 요청 헤더 설정 : 브라우저 정보
req_header = {
   'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers=req_header)
print(res)
print(type(res))
print(res.status_code, res.ok) 


# 응답(response)이 OK 이면
if res.ok:
    # 응답 (response)에서 text 추출
    html = res.text
    # print(html)
    # BeautifulSoup 객체 생성  
    soup = BeautifulSoup(html,'html.parser')
    print(soup)
    # CSS 선택자
    # <div class='sa_text'><a></a></div?
    print(len(soup.select("div.sa_text a[href*='mnews/article']")))
    # print(soup.select("div.sa_text a[href*='mnews/article']"))
    a_tag_list = soup.select("div.sa_text a[href*='mnews/article']")
    print(type(a_tag_list)) #ResultSet
    for a_tag in a_tag_list:
        #print(type(a_tag))
        title = a_tag.text.strip()
        #href 속성에 값을 가져온다.
        link = a_tag['href']
        print(link, title)

    # <a> 태그 리스트 순회하기    
else:
    # 응답(response)이 Error 이면 status code 출력
    print(f'에러 코드 = {res.status_code}')
# Out:
# https://news.naver.com/section/105
# <Response [200]>
# <class 'requests.models.Response'>
# 200 True
# <!DOCTYPE html>
#
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="IT/과학 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/section/105" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="IT/과학 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공" name="twitter:description"/>
# <title>IT/과학 : 네이버 뉴스</title>
# <link href="https://static-nnews.pstatic.net/css/min/20250403/news.css" rel="stylesheet"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" rel="apple-touch-icon-precomposed" size="72x72"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" rel="apple-touch-icon-precomposed" size="96x96"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" rel="apple-touch-icon-precomposed" size="144x144"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed" size="192x192"/>
# <script>
# 			var bSupportedIntersectionObserver = "IntersectionObserver" in window;
# 		</script>
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# <script>
# 			var g_ssc = nsc = "news.v3_sec";
# 			var g_default_area = "itn";
#
# 			var svr = "one-service-h-20250403-250407-211653-6878c6d4-9fvbj";
# 			var nelo = {
# 				name : "one-front",
# 				url : "https://kr-col-ext.nelo.navercorp.com/_store",
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "";
# 			var layoutName = "section_home";
# 			var layoutType = "section";
# 			var isAvailableDarkMode = false;
# 			var moduleLoadStatus = -1;
#
# 			var article = {
#
# 				officeId: "",
# 				articleId: "",
# 				sectionId : "",
# 				gdid: "",
# 				type: "",
# 				sectionInfo: {
# 					firstSection: "",
# 					secondSection: "",
# 					thirdSection: ""
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: false,
# 				isPressHome: false,
# 				name : "",
# 				category : ""
# 			};
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newslist",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: false,
# 					hasSid1: true
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: true,
# 					hasSid1: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
# 					var hasSid1 = adInfo.hasSid1;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "shome";
# 					}
# 					if (hasSid1 == true) {
# 						customParam.sid1 = "105";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# <script src="https://static-nnews.pstatic.net/js/min/20250403b/common.min.js"></script>
# </link></meta></head>
# <body class="n_news_mnews fs1 as_mp_layout as_section_home">
# <div class="end_container">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <header class="as_gnb_mnews as_type_section" role="banner">
# <div class="header_inner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link _LINK" data-clk="gnb.naver" data-pc-url="https://www.naver.com/" data-url="https://m.naver.com/" href="https://m.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a class="_LINK" data-clk="gnb.news" data-pc-url="https://news.naver.com/" data-url="https://m.news.naver.com" href="https://m.news.naver.com"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.entertain" data-pc-url="https://entertain.naver.com/home" data-url="https://m.entertain.naver.com" href="https://m.entertain.naver.com">
# <span class="Nicon_family Nicon_entertain">엔터</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.sports" data-pc-url="https://sports.news.naver.com/index" data-url="https://m.sports.naver.com" href="https://m.sports.naver.com">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.weather" href="https://weather.naver.com">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.premium" href="https://contents.premium.naver.com">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho" href="javascript:;"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb" data-scroll-fixed="true" id="_LNB_PARENT_WRAP" style="z-index:3000;">
# <div class="Nlnb_menu Ntype_scroll" id="_LNB_WRAP">
# <div class="Nlnb_menu_inner" id="_LNB">
# <ul class="Nlnb_menu_list" role="tablist">
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.press" href="https://news.naver.com/" role="tab"><span class="Nitem_link_menu">언론사별</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.pol" href="https://news.naver.com/section/100" role="tab"><span class="Nitem_link_menu">정치</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.eco" href="https://news.naver.com/section/101" role="tab"><span class="Nitem_link_menu">경제</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.soc" href="https://news.naver.com/section/102" role="tab"><span class="Nitem_link_menu">사회</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.lif" href="https://news.naver.com/section/103" role="tab"><span class="Nitem_link_menu">생활/문화</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM is_active" role="presentation">
# <a aria-selected="true" class="Nitem_link" data-clk="lnb.it" href="https://news.naver.com/section/105" role="tab"><span class="Nitem_link_menu">IT/과학</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.wor" href="https://news.naver.com/section/104" role="tab"><span class="Nitem_link_menu">세계</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.rank" href="https://news.naver.com/main/ranking/popularDay.naver?mid=etc&amp;sid1=111" role="tab"><span class="Nitem_link_menu">랭킹</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.paper" href="https://news.naver.com/newspaper/home" role="tab"><span class="Nitem_link_menu">신문보기</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.opi" href="https://news.naver.com/main/opinion/home.naver" role="tab"><span class="Nitem_link_menu">오피니언</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.tv" href="https://news.naver.com/main/tv/index.naver?mid=tvh" role="tab"><span class="Nitem_link_menu">TV</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.fact" href="https://news.naver.com/main/factcheck/main.naver" role="tab"><span class="Nitem_link_menu">팩트체크</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.algo" href="https://media.naver.com/algorithm" role="tab"><span class="Nitem_link_menu">알고리즘 안내</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.correct" href="https://news.naver.com/ombudsman/errorArticleList" role="tab"><span class="Nitem_link_menu">정정보도 모음</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <hr/>
# <script>
# 	var svt = "20250408155104.427";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var nilNtmUrl = "https://ntm.pstatic.net/scripts/ntm_b7032129a433.js";
#
# 	var envPhase = "production";
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# 	var gnb_item_hide_option = 128;
#
# 	var isDegradeMode = false;
# 	var isDegradeN2Mode = false;
# </script>
# <div class="ct_wrap" id="ct_wrap">
# <div class="ct_lnb">
# <div class="ct_lnb_inner">
# <strong class="ct_lnb_date">04.08(화)</strong>
# <ul class="ct_lnb_side">
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.allmedia" href="https://news.naver.com/main/officeList.naver">전체 언론사</a>
# </li>
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.newsstand" href="https://newsstand.naver.com/" target="_blank">뉴스스탠드</a>
# </li>
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.library" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank">라이브러리</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="ct_scroll_wrapper">
# <div class="column0">
# <div class="ct_snb">
# <h2 class="ct_snb_h2">
# <a class="ct_snb_h2_a" data-clk="lmn_itn.home" href="/section/105">IT/과학</a>
# </h2>
# <ul class="ct_snb_nav">
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="1" href="/breakingnews/section/105/731">모바일</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="2" href="/breakingnews/section/105/226">인터넷/SNS</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="3" href="/breakingnews/section/105/227">통신/뉴미디어</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="4" href="/breakingnews/section/105/230">IT 일반</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="5" href="/breakingnews/section/105/732">보안/해킹</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="6" href="/breakingnews/section/105/283">컴퓨터</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="7" href="/breakingnews/section/105/229">게임/리뷰</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="8" href="/breakingnews/section/105/228">과학 일반</a>
# </li>
# </ul>
# <div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <a data-clk="lmn_itn.pmb" data-rank="1" href="https://media.naver.com/algorithm">
# <img alt="AI 뉴스 알고리즘 안내" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/10/184436024_banner_left.png" height="74" style="display: none;" width="71"/>
# </a>
# </div>
# <div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <a data-clk="lmn_itn.pmb" data-rank="2" href="https://contents.premium.naver.com/">
# <img alt="프리미엄콘텐츠" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" height="74" style="display: none;" width="71"/>
# </a>
# </div>
# </div>
# </div>
# <div class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT" id="newsct" role="main"><div class="section_component as_section_headline _PERSIST_CONTENT" data-persist="2_sectionHeadline">
# <div class="section_article as_headline _TEMPLATE" data-template-id="SECTION_HEADLINE">
# <div class="sa_head">
# <span class="sa_head_inner">
# <a class="sa_head_link _TOGGLE" data-classvalue="is_hidden" data-clk="guide" data-target="_SECTION_HEADLINE_INFO_nz4dy" href="#">헤드라인 뉴스 <i class="sa_head_icon">안내</i></a>
# </span>
# <div class="sa_head_layer is_hidden" id="_SECTION_HEADLINE_INFO_nz4dy">
# <p class="sa_head_layer_p">각 헤드라인의 기사와 배열 순서는 개인화를 반영해 추천되며, 기사묶음의 대표 기사는 구독 언론사 중심으로 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 자동 추출됩니다.</p>
# <a class="sa_head_layer_go" href="https://media.naver.com/algorithm">알고리즘 자세히 보기</a>
# <div class="sa_head_layer_close">
# <button class="_TOGGLE" data-classvalue="is_hidden" data-target="_SECTION_HEADLINE_INFO_nz4dy" type="button">닫기</button>
# </div>
# </div>
# </div>
# <ul class="sa_list" id="_SECTION_HEADLINE_LIST_nz4dy">
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000AF_000000000000000002177123" data-imp-index="1" data-imp-url="https://n.news.naver.com/mnews/article/052/0002177123" href="https://n.news.naver.com/mnews/article/052/0002177123">
# <strong class="sa_text_strong">우주청, 우즈베키스탄·이탈리아와 손잡고 우주 국제협력 본격화</strong>
# </a>
# <div class="sa_text_lede">우주항공청이 지난 7일 미국 콜로라도 스프링스에서 열린 '2025 스페이스 심포지엄'에 참석해 우즈베키스탄·이탈리아 우주청과 업무협약을 맺었습니다. 우주청은 우즈베키스탄과 위성개발, 우주 인력양성 등 다양한 분야에서</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">YTN</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news052,0002177123" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/052/0002177123" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202504080940_00000004/section/105?oid=052&amp;aid=0002177123">
# <span class="sa_text_cluster_num">19</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000F2_000000000000000003432668" data-imp-index="2" data-imp-url="https://n.news.naver.com/mnews/article/025/0003432668" href="https://n.news.naver.com/mnews/article/025/0003432668">
# <img alt="기업은행 SKT와 손잡고, 보이스피싱 AI로 실시간 탐지한다" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/025/2025/04/08/3432668.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000F2_000000000000000003432668" data-imp-index="2" data-imp-url="https://n.news.naver.com/mnews/article/025/0003432668" href="https://n.news.naver.com/mnews/article/025/0003432668">
# <strong class="sa_text_strong">기업은행 SKT와 손잡고, 보이스피싱 AI로 실시간 탐지한다</strong>
# </a>
# <div class="sa_text_lede">IBK기업은행이 SK텔레콤과 손잡고 ‘인공지능(AI) 보이스피싱 피해·탐지 서비스’를 시작했다. 금융사고 의심 거래가 발생하면, SK텔레콤의 AI 시스템을 활용해 보이스피싱 여부를 탐지하고 이를 고객에게 통지하는 방</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">중앙일보</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news025,0003432668" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/025/0003432668" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202504061540_00000172/section/105?oid=025&amp;aid=0003432668">
# <span class="sa_text_cluster_num">44</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="08138263_000000000000000008180201" data-imp-index="3" data-imp-url="https://n.news.naver.com/mnews/article/421/0008180201" href="https://n.news.naver.com/mnews/article/421/0008180201">
# <img alt="&quot;생활형 AI 시대 연다&quot;…뤼튼테크놀로지스 '뤼튼 3.0' 발표" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/421/2025/04/08/8180201.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="08138263_000000000000000008180201" data-imp-index="3" data-imp-url="https://n.news.naver.com/mnews/article/421/0008180201" href="https://n.news.naver.com/mnews/article/421/0008180201">
# <strong class="sa_text_strong">"생활형 AI 시대 연다"…뤼튼테크놀로지스 '뤼튼 3.0' 발표</strong>
# </a>
# <div class="sa_text_lede">뤼튼테크놀로지스는 8일 서울 광화문 포시즌스 호텔에서 '프레스 콘퍼런스'를 열고 생활형 인공지능(AI) 시대를 이끌 '뤼튼 3.0' 전략을 발표했다. 이세영 대표는 "생성형 AI에서 생활형 AI로 진화하겠다"며 "누</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">뉴스1</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news421,0008180201" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/421/0008180201" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202504081210_00001805/section/105?oid=421&amp;aid=0008180201">
# <span class="sa_text_cluster_num">20</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000C4_000000000000000002701759" data-imp-index="4" data-imp-url="https://n.news.naver.com/mnews/article/021/0002701759" href="https://n.news.naver.com/mnews/article/021/0002701759">
# <img alt="스미싱 등 악성 문자, 발송단계부터 차단한다" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/021/2025/04/08/2701759.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000C4_000000000000000002701759" data-imp-index="4" data-imp-url="https://n.news.naver.com/mnews/article/021/0002701759" href="https://n.news.naver.com/mnews/article/021/0002701759">
# <strong class="sa_text_strong">스미싱 등 악성 문자, 발송단계부터 차단한다</strong>
# </a>
# <div class="sa_text_lede">과기정통부, ‘엑스레이 서비스’ 시범 운영 잊을 만하면 찾아오는 불청객, 악성 문자를 사전에 차단할 수 있는 서비스가 운영된다. 과학기술정보통신부와 한국인터넷진흥원(KISA)은 스미싱 등 악성 문자를 발송 단계에서부</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">문화일보</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news021,0002701759" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/021/0002701759" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202504081210_00000024/section/105?oid=021&amp;aid=0002701759">
# <span class="sa_text_cluster_num">16</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000BC_000000000000000005472817" data-imp-index="5" data-imp-url="https://n.news.naver.com/mnews/article/009/0005472817" href="https://n.news.naver.com/mnews/article/009/0005472817">
# <img alt="“1초만에 99.5% 정확도로 상품 인식”…신세계아이앤씨, AI 리테일테크 시장 정조준" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/009/2025/04/08/5472817.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000BC_000000000000000005472817" data-imp-index="5" data-imp-url="https://n.news.naver.com/mnews/article/009/0005472817" href="https://n.news.naver.com/mnews/article/009/0005472817">
# <strong class="sa_text_strong">“1초만에 99.5% 정확도로 상품 인식”…신세계아이앤씨, AI 리테일테크 시장 정조준</strong>
# </a>
# <div class="sa_text_lede">AI 접목 무인매장부터 공간 데이터 분석까지 리테일테크 시장 확대 신세계아이앤씨(신세계I&amp;C)는 리테일(유통) 산업에 특화된 ‘스파로스 인공지능(AI) 비전’(Spharos AI Vision) 기반 설루션 라인업을 </div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">매일경제</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news009,0005472817" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/009/0005472817" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202504080750_00000002/section/105?oid=009&amp;aid=0005472817">
# <span class="sa_text_cluster_num">8</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000E7_000000000000000005982223" data-imp-index="6" data-imp-url="https://n.news.naver.com/mnews/article/018/0005982223" href="https://n.news.naver.com/mnews/article/018/0005982223">
# <img alt="카카오의 소상공인 판로 제공 실험 결실…착한 소비 1조원 돌파" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/018/2025/04/08/5982223.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000E7_000000000000000005982223" data-imp-index="6" data-imp-url="https://n.news.naver.com/mnews/article/018/0005982223" href="https://n.news.naver.com/mnews/article/018/0005982223">
# <strong class="sa_text_strong">카카오의 소상공인 판로 제공 실험 결실…착한 소비 1조원 돌파</strong>
# </a>
# <div class="sa_text_lede">2021년 8월 시작한 ‘제가버치’는 우리 농축수산물과 가공식품이 제값을 다 할 수 있도록 판로를 열어주고 있다. 수급을 맞추지 못해 버려지는 농산물들에 대해 농어민의 부담은 덜고, 수요와 공급을 안정시켜 시장 가격</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">이데일리</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news018,0005982223" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/018/0005982223" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202504080920_00000019/section/105?oid=018&amp;aid=0005982223">
# <span class="sa_text_cluster_num">15</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000D8_000000000000000015316565" data-imp-index="7" data-imp-url="https://n.news.naver.com/mnews/article/001/0015316565" href="https://n.news.naver.com/mnews/article/001/0015316565">
# <img alt="생명硏, 슈퍼박테리아 내성 극복한 신규 항생제 개발" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/001/2025/04/08/15316565.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000D8_000000000000000015316565" data-imp-index="7" data-imp-url="https://n.news.naver.com/mnews/article/001/0015316565" href="https://n.news.naver.com/mnews/article/001/0015316565">
# <strong class="sa_text_strong">생명硏, 슈퍼박테리아 내성 극복한 신규 항생제 개발</strong>
# </a>
# <div class="sa_text_lede">생물학에 나노기술 접목해 새로운 항생제 치료법 제시 한국생명공학연구원은 감염병연구센터 류충민 박사 연구팀이 슈퍼박테리아를 효과적으로 제어할 수 있는 금 나노입자와 지질 나노입자 기반 신규 항생제를 개발했다고 8일 밝</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">연합뉴스</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news001,0015316565" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/001/0015316565" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202504080940_00000191/section/105?oid=001&amp;aid=0015316565">
# <span class="sa_text_cluster_num">9</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="section_more _SECTION_HEADLINE_MORE_BUTTON_WRAP">
# <a class="section_more_inner _SECTION_HEADLINE_MORE_BUTTON _NLOG_IMPRESSION_TRIGGER" data-clk="clsmore" data-target="_SECTION_HEADLINE_LIST_nz4dy" href="#">헤드라인 더보기</a>
# </div>
# </div>
# <div class="section_component as_section_series _PERSIST_CONTENT" data-persist="3_sectionSeries">
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# <div class="ss_head">
# <div class="ss_head_inner">
# <a class="ss_head_link" data-clk="sert" href="https://news.naver.com/hotissue/main?sid1=163&amp;cid=2000113">
# <span class="ss_head_go">연재보기</span>
# <h2 class="ss_head_topic">소부장반차장</h2>
# </a>
# </div>
# </div>
# <div class="ss_body">
# <ul class="ss_list">
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002194264" data-imp-index="kncny" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002194264?type=series&amp;cid=2000113" href="https://n.news.naver.com/mnews/hotissue/article/138/0002194264?type=series&amp;cid=2000113">
# <img alt="DDR5 가격 불 붙인 中 CXMT…삼성⋅SK '반사이익' 장기화 기대" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/138/2025/04/08/2194264.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002194264" data-imp-index="kncny" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002194264?type=series&amp;cid=2000113" href="https://n.news.naver.com/mnews/hotissue/article/138/0002194264?type=series&amp;cid=2000113">DDR5 가격 불 붙인 中 CXMT…삼성⋅SK '반사이익' 장기화 기대</a>
# <div class="ss_text_lede">중국 메모리 기업 CXMT(Changxin Memory Technologies)가 1B 나노 기반 DDR5 제품에서 불량 문제를 겪고 있는 것으로 알려지면서, 현물 시장에서 DDR5 가격이 반등세를 타고 있다. 공급</div>
# <div class="ss_text_info">
# <div class="ss_text_press">디지털데일리</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news138,0002194264" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/138/0002194264" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002194253" data-imp-index="8aghp" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002194253?type=series&amp;cid=2000113" href="https://n.news.naver.com/mnews/hotissue/article/138/0002194253?type=series&amp;cid=2000113">
# <img alt="HCL테크, 삼성전자 파운드리 설계 파트너로 합류…SAFE DSP 선정" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/138/2025/04/08/2194253.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002194253" data-imp-index="8aghp" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002194253?type=series&amp;cid=2000113" href="https://n.news.naver.com/mnews/hotissue/article/138/0002194253?type=series&amp;cid=2000113">HCL테크, 삼성전자 파운드리 설계 파트너로 합류…SAFE DSP 선정</a>
# <div class="ss_text_lede">인도 선도 기술기업 HCL테크(HCLTech)가 삼성전자의 반도체 파운드리 생태계 프로그램 'SAFE™(Samsung Advanced Foundry Ecosystem)'의 설계 솔루션 파트너(DSP)로 선정됐다고 8</div>
# <div class="ss_text_info">
# <div class="ss_text_press">디지털데일리</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news138,0002194253" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/138/0002194253" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002193939" data-imp-index="sgrqt" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002193939?type=series&amp;cid=2000113" href="https://n.news.naver.com/mnews/hotissue/article/138/0002193939?type=series&amp;cid=2000113">
# <img alt="반도체 업계, 1Q 바닥 다지고 날아오를까…범용 메모리에 훈풍 분다" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/138/2025/04/02/2193939.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002193939" data-imp-index="sgrqt" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002193939?type=series&amp;cid=2000113" href="https://n.news.naver.com/mnews/hotissue/article/138/0002193939?type=series&amp;cid=2000113">반도체 업계, 1Q 바닥 다지고 날아오를까…범용 메모리에 훈풍 분다</a>
# <div class="ss_text_lede">올해 1분기 실적 발표를 앞둔 국내 양대 메모리반도체 기업인 삼성전자와 SK하이닉스가 비수기 진입, 범용 제품의 가격 하락에 따른 실적 부진이 예고됐다. 다만 2분기부터 메모리 가격이 상승하는 흐름이 이어지면서 점차</div>
# <div class="ss_text_info">
# <div class="ss_text_press">디지털데일리</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news138,0002193939" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/138/0002193939" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002193937" data-imp-index="rg26x" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002193937?type=series&amp;cid=2000113" href="https://n.news.naver.com/mnews/hotissue/article/138/0002193937?type=series&amp;cid=2000113">
# <img alt="&quot;AI 메모리 韓이 꽉 잡았는데&quot;…美 트럼프 관세 부과 '자충수' 가능성도" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/138/2025/04/02/2193937.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002193937" data-imp-index="rg26x" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002193937?type=series&amp;cid=2000113" href="https://n.news.naver.com/mnews/hotissue/article/138/0002193937?type=series&amp;cid=2000113">"AI 메모리 韓이 꽉 잡았는데"…美 트럼프 관세 부과 '자충수' 가능성도</a>
# <div class="ss_text_lede">도널드 트럼프 미국 대통령이 반도체를 포함한 외국산 전략 기술 제품에 25% 고율 관세 부과를 검토하면서, 글로벌 공급망 긴장이 고조되고 있다. 수출 의존도가 높은 한국 반도체 업계에도 긴장감이 돌고 있지만, 정작 </div>
# <div class="ss_text_info">
# <div class="ss_text_press">디지털데일리</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news138,0002193937" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/138/0002193937" style="display: none;"></a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# <div class="ss_head">
# <div class="ss_head_inner">
# <a class="ss_head_link" data-clk="sert" href="https://news.naver.com/hotissue/main?sid1=163&amp;cid=2002669">
# <span class="ss_head_go">연재보기</span>
# <h2 class="ss_head_topic">AI는 지금</h2>
# </a>
# </div>
# </div>
# <div class="ss_body">
# <ul class="ss_list">
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002369708" data-imp-index="8c957" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002369708?type=series&amp;cid=2002669" href="https://n.news.naver.com/mnews/hotissue/article/092/0002369708?type=series&amp;cid=2002669">
# <img alt="&quot;아이폰 시대 곧 끝날까&quot;…오픈AI, 애플 디자이너 스타트업 인수 '만지작'" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/092/2025/04/07/2369708.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002369708" data-imp-index="8c957" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002369708?type=series&amp;cid=2002669" href="https://n.news.naver.com/mnews/hotissue/article/092/0002369708?type=series&amp;cid=2002669">"아이폰 시대 곧 끝날까"…오픈AI, 애플 디자이너 스타트업 인수 '만지작'</a>
# <div class="ss_text_lede">"인공지능(AI)은 컴퓨터와 접하는 방법이 근본적으로 다릅니다. 새로운 단말기가 필요한 상태로, 음성 조작이 핵심이 될 것입니다." 지난 2월 일본 니혼게이자이신문(닛케이)과의 인터뷰에서 이처럼 밝혔던 샘 알트먼 오</div>
# <div class="ss_text_info">
# <div class="ss_text_press">ZDNet Korea</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news092,0002369708" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/092/0002369708" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002369365" data-imp-index="rztkw" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002369365?type=series&amp;cid=2002669" href="https://n.news.naver.com/mnews/hotissue/article/092/0002369365?type=series&amp;cid=2002669">
# <img alt="&quot;AI의 미터법 될까&quot;…앤트로픽 MCP, 생태계 '공용어' 부상" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/092/2025/04/04/2369365.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002369365" data-imp-index="rztkw" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002369365?type=series&amp;cid=2002669" href="https://n.news.naver.com/mnews/hotissue/article/092/0002369365?type=series&amp;cid=2002669">"AI의 미터법 될까"…앤트로픽 MCP, 생태계 '공용어' 부상</a>
# <div class="ss_text_lede">"이제는 지식 탐색과 코드 자동화가 현실화될 정도로 인공지능(AI) 모델이 발전했습니다. 단순히 답을 잘하는 AI가 아니라 현실 데이터를 탐색하고 툴을 활용해 실제 작업을 수행하는 AI가 가능한 시점에 도달한 겁니다</div>
# <div class="ss_text_info">
# <div class="ss_text_press">ZDNet Korea</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news092,0002369365" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/092/0002369365" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002369123" data-imp-index="1q9ds" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002369123?type=series&amp;cid=2002669" href="https://n.news.naver.com/mnews/hotissue/article/092/0002369123?type=series&amp;cid=2002669">
# <img alt="샘 알트먼, 챗GPT 가입자 5억명 돌파 자축 '눈총'…왜?" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/092/2025/04/02/2369123.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002369123" data-imp-index="1q9ds" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002369123?type=series&amp;cid=2002669" href="https://n.news.naver.com/mnews/hotissue/article/092/0002369123?type=series&amp;cid=2002669">샘 알트먼, 챗GPT 가입자 5억명 돌파 자축 '눈총'…왜?</a>
# <div class="ss_text_lede">"샘 알트먼이 특정 작가의 저작권을 침해하는 방식으로 제품을 홍보하는 것 자체가 얼마나 그가 저작권에 무심한 지를 보여주는 것 같아요." 샘 알트먼 오픈AI 최고경영자(CEO)가 저작권 침해 문제를 두고 또 다시 도</div>
# <div class="ss_text_info">
# <div class="ss_text_press">ZDNet Korea</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news092,0002369123" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/092/0002369123" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002368874" data-imp-index="ipjaz" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002368874?type=series&amp;cid=2002669" href="https://n.news.naver.com/mnews/hotissue/article/092/0002368874?type=series&amp;cid=2002669">
# <img alt="中 딥시크 파장 컸나…폐쇄형 고집하던 오픈AI, '오픈소스 모델' 출시" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/092/2025/04/01/2368874.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002368874" data-imp-index="ipjaz" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002368874?type=series&amp;cid=2002669" href="https://n.news.naver.com/mnews/hotissue/article/092/0002368874?type=series&amp;cid=2002669">中 딥시크 파장 컸나…폐쇄형 고집하던 오픈AI, '오픈소스 모델' 출시</a>
# <div class="ss_text_lede">중국 인공지능(AI) 기업 딥시크의 부상에 자극을 받은 오픈AI가 폐쇄 정책에서 벗어나 오픈소스 전략에 힘을 주고 있다. 오픈소스 진영과 폐쇄형 진영의 기술 격차가 점차 줄어들며 오픈소스 생태계가 빠르게 확산되자 위</div>
# <div class="ss_text_info">
# <div class="ss_text_press">ZDNet Korea</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news092,0002368874" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/092/0002368874" style="display: none;"></a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="r_group_comp ad_box _da_banner _PERSIST_HEIGHT is_border_none" data-persist="1_ad">
# <div class="ad_area _AD_WRAP" data-article="false" data-mobileonly="false" data-sync="false" data-unitid="p_news_newslist" id="nmap_c____1"></div>
# </div>
# <div class="section_latest">
# <div class="section_component as_section_article_list _PERSIST_CONTENT" data-persist="SECTION_ARTICLE_LIST">
# <div class="section_latest_article _CONTENT_LIST _PERSIST_META" data-cluid="" data-cursor="20250408134818" data-cursor-name="next" data-date="" data-has-next="true" data-nclk="airscont" data-page-no="1" data-persist="SECTION_ARTICLE_LIST_META" data-persist-meta-restore="true" data-sid="105" data-sid2="" data-template="SECTION_ARTICLE_LIST">
# <div class="section_article _TEMPLATE" data-template-id="SECTION_ARTICLE_LIST">
# <ul class="sa_list">
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"ZnYZW00fQE6h4qZ1"}}' data-gdid="8800011E_000000000000000002369827" data-imp-url="https://n.news.naver.com/mnews/article/092/0002369827" data-rank="1" href="https://n.news.naver.com/mnews/article/092/0002369827">
# <img alt='리플 "전 세계 금융 시장, 실물자산 토큰화 중심으로 근본 변화"' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/092/2025/04/08/2369827.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"ZnYZW00fQE6h4qZ1"}}' data-gdid="8800011E_000000000000000002369827" data-imp-url="https://n.news.naver.com/mnews/article/092/0002369827" data-rank="1" href="https://n.news.naver.com/mnews/article/092/0002369827">
# <strong class="sa_text_strong">리플 "전 세계 금융 시장, 실물자산 토큰화 중심으로 근본 변화"</strong>
# </a>
# <div class="sa_text_lede">리플은 보스턴컨설팅그룹(BCG)과 공동 발간한 보고서를 통해 전 세계 금융 시장은 실물자산의 토큰화를 중심으로 근본적인 변화를 겪고 있다고 7일(현지시간) 밝혔다. 관련 시장 규모는 현재 약 6천억 달러에서 2030</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">지디넷코리아</div>
# <div class="sa_text_datetime is_recent">
# <b>32분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news092,0002369827" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/092/0002369827" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"ZnYZW00fQE6h4qZ1"}}' data-gdid="08138263_000000000000000008180569" data-imp-url="https://n.news.naver.com/mnews/article/421/0008180569" data-rank="2" href="https://n.news.naver.com/mnews/article/421/0008180569">
# <img alt="에이비엘바이오, '4조 기술이전' 후 첫 공식석상…로드맵 밝힌다" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/421/2025/04/08/8180569.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"ZnYZW00fQE6h4qZ1"}}' data-gdid="08138263_000000000000000008180569" data-imp-url="https://n.news.naver.com/mnews/article/421/0008180569" data-rank="2" href="https://n.news.naver.com/mnews/article/421/0008180569">
# <strong class="sa_text_strong">에이비엘바이오, '4조 기술이전' 후 첫 공식석상…로드맵 밝힌다</strong>
# </a>
# <div class="sa_text_lede">국내외 제약 및 바이오업계의 관심을 집중적으로 받고 있는 에이비엘바이오(298380)가 최근 글로벌 제약사 GSK와의 대규모 기술이전 계약 체결 이후 첫 소통의 장을 마련한다. 에이비엘바이오는 9일 기업설명회(IR)</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">뉴스1</div>
# <div class="sa_text_datetime is_recent">
# <b>38분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news421,0008180569" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/421/0008180569" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"ZnYZW00fQE6h4qZ1"}}' data-gdid="08138263_000000000000000008180565" data-imp-url="https://n.news.naver.com/mnews/article/421/0008180565" data-rank="3" href="https://n.news.naver.com/mnews/article/421/0008180565">
# ...
# 			{{/journalist}}
# </script>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_ALL"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_OS"></div>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="" onerror="this.outerHTML='<span class=&quot;no_image&quot;></span>'">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_OS" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="napp_notify_notice">
# 	<div class="napp_notify_info_area">
# 		<strong class="napp_notify_title">네이버 앱 푸시알림이 꺼져있어요.</strong>
# 		<div class="napp_notify_desc_box">
# 			<p class="napp_notify_desc1">네이버 앱 알림켜기 &gt; 알림탭 &gt; 알림허용</p>
# 			<p class="napp_notify_desc2">버튼을 눌러 앱 알림 설정을 켜주세요.</p>
# 		</div>
# 	</div>
# 	<div class="napp_notify_button_area">
# 		<button type="button" class="napp_notify_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}.osnotoff">닫기</button>
# 		<button type="button" class="napp_notify_btn highlight _MODAL_LAYER_POSITIVE _NAPP_NOTIFY_COMPLETE" data-clk="{{nclk}}.osnoton">네이버 앱 알림 켜기</button>
# 	</div>
# </div>
# </div>
# </script>
# <div id="_MODAL_DIALOG_WRAP" style="display: none;"></div>
# <script class="_MODAL_DIALOG_TEMPLATE" type="x-tmpl-mustache">
# <div class="nds_dialog_dimmed">
# 	<div class="nds_dialog_basic">
# 		<div class="nds_dialog_content">
# 			{{#isTextType}}
# 			<p class="nds_dialog_text">{{content.title}}</p>
# 			{{/isTextType}}
# 			{{#isTitleType}}
# 			<strong class="nds_dialog_title">
# 				<span class="nds_dialog_title_ellipsis">{{content.headTitle}}</span>
# 				{{content.title}}
# 			</strong>
# 			<p class="nds_dialog_description">{{content.description}}</p>
# 			{{/isTitleType}}
# 		</div>
# 		<div class="nds_dialog_button_area">
# 			<div class="nds_button_main_action as_layout_5_5">
# 				{{#isCancel}}
# 				<button type="button" class="nds_button_wide _MODAL_CANCEL"{{#content.clk.cancelClk}} data-clk="{{content.clk.cancelClk}}"{{/content.clk.cancelClk}}>
# 				{{content.cancelMessage}}
# 				</button>
# 				{{/isCancel}}
# 				<button type="button" class="nds_button_wide as_primary _MODAL_CONFIRM"{{#content.clk.confirmClk}} data-clk="{{content.clk.confirmClk}}"{{/content.clk.confirmClk}}>
# 				{{content.confirmMessage}}
# 				</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div id="_MODAL_TOAST" style="display: none;"></div>
# <script class="_MODAL_TOAST_TEMPLATE" type="x-tmpl-mustache">
# <div class="nds_popover_toast as_center">
# 	<div class="nds_toast_text_area">
# 		<div class="nds_toast_text_area"><span class="nds_toast_ellipsis_text"><strong>{{toastTitle}}</strong></span> {{toastMessage}}</div>
# 	</div>
# </div>
# </script>
# <div class="ticker" id="_TICKER_LAYER_FOR_NOTIFICATION" style="display: none;"></div>
# <script class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script crossorigin="anonymous" onerror="neloSender.sendErrorToNelo('스크립트 로딩 에러 : ' + this.src);" src="https://static-nnews.pstatic.net/js/min/20250403b/library.min.js"></script>
# <script crossorigin="anonymous" onerror="neloSender.sendErrorToNelo('스크립트 로딩 에러 : ' + this.src);" src="https://static-nnews.pstatic.net/js/min/20250403b/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {};
# 		var redirectSection = {"id":"105","name":"IT"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports || service.newsType) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		var issueComponentId = $("._ISSUE_ARTICLE_INFO").attr("data-component-id");
# 		ntmOption["dimension8"] = issueComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)|(www\.naver\.com)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false && $("#contents").length > 0) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("onpagehide" in window ? "pagehide" : "beforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onpagehide" in window ? "onpagehide" : "onbeforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var onUnloadEventName = "onpagehide" in window ? "onpagehide" : "onbeforeunload";
# 				var fnOnUnload = window[onUnloadEventName];
# 				window[onUnloadEventName] = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# </div>
# <script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				window.ntm = window.ntm || [];
#
# 				var pageviewInfo = {
# 					event: "nLogPageViewService",
# 					nlogEvt: {
# 						page_layout: window.layoutName
# 					}
# 				};
#
# 				pageviewInfo.nLogPageviewSti = "news";
#
# 				window.ntm.push(pageviewInfo);
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": "섹션홈"
# 					},
# 					"extraInfo": {
# 						"sectionId": "105"
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
#
# 				setTimeout(function() {
# 					$("._OPACITY_FADE_TO").fadeTo(50, 1);
# 				}, 3000);
# 			});
# 		</script>
# </body>
# </html>
#
# 86
# <class 'bs4.element.ResultSet'>
# https://n.news.naver.com/mnews/article/052/0002177123 우주청, 우즈베키스탄·이탈리아와 손잡고 우주 국제협력 본격화
# https://n.news.naver.com/mnews/article/comment/052/0002177123
# https://n.news.naver.com/mnews/article/025/0003432668 기업은행 SKT와 손잡고, 보이스피싱 AI로 실시간 탐지한다
# https://n.news.naver.com/mnews/article/comment/025/0003432668
# https://n.news.naver.com/mnews/article/421/0008180201 "생활형 AI 시대 연다"…뤼튼테크놀로지스 '뤼튼 3.0' 발표
# https://n.news.naver.com/mnews/article/comment/421/0008180201
# https://n.news.naver.com/mnews/article/021/0002701759 스미싱 등 악성 문자, 발송단계부터 차단한다
# https://n.news.naver.com/mnews/article/comment/021/0002701759
# https://n.news.naver.com/mnews/article/009/0005472817 “1초만에 99.5% 정확도로 상품 인식”…신세계아이앤씨, AI 리테일테크 시장 정조준
# https://n.news.naver.com/mnews/article/comment/009/0005472817
# https://n.news.naver.com/mnews/article/018/0005982223 카카오의 소상공인 판로 제공 실험 결실…착한 소비 1조원 돌파
# https://n.news.naver.com/mnews/article/comment/018/0005982223
# https://n.news.naver.com/mnews/article/001/0015316565 생명硏, 슈퍼박테리아 내성 극복한 신규 항생제 개발
# https://n.news.naver.com/mnews/article/comment/001/0015316565
# https://n.news.naver.com/mnews/article/092/0002369827 리플 "전 세계 금융 시장, 실물자산 토큰화 중심으로 근본 변화"
# https://n.news.naver.com/mnews/article/comment/092/0002369827
# https://n.news.naver.com/mnews/article/421/0008180569 에이비엘바이오, '4조 기술이전' 후 첫 공식석상…로드맵 밝힌다
# https://n.news.naver.com/mnews/article/comment/421/0008180569
# https://n.news.naver.com/mnews/article/421/0008180565 "의료계 제안 논의하자"…의협, 정부·국회에 '대화의 장' 요구
# https://n.news.naver.com/mnews/article/comment/421/0008180565
# https://n.news.naver.com/mnews/article/081/0003531724 항암제 피하는 암세포 꼼수 발견…악성 폐암도 잡는다
# https://n.news.naver.com/mnews/article/comment/081/0003531724
# https://n.news.naver.com/mnews/article/421/0008180537 뤼튼 "무료전략으로 생활형 AI 시대 열 것…올해 천만 MAU 목표"
# https://n.news.naver.com/mnews/article/comment/421/0008180537
# https://n.news.naver.com/mnews/article/032/0003361993 첫 한국계 ‘NASA 우주비행사’ 조니 김, 마침내 지구 궤도로 떠났다
# https://n.news.naver.com/mnews/article/comment/032/0003361993
# https://n.news.naver.com/mnews/article/015/0005116525 질병청, 세계 첫 단백질 재조합 탄저백신 '배리트락스' 상용화
# https://n.news.naver.com/mnews/article/comment/015/0005116525
# https://n.news.naver.com/mnews/article/092/0002369818 트럼프 관세, 세계경제 큰 타격…美中 충돌로 더 증폭
# https://n.news.naver.com/mnews/article/comment/092/0002369818
# https://n.news.naver.com/mnews/article/366/0001067643 [100세 과학] 노년 건강 유지엔 채식보다 육식
# https://n.news.naver.com/mnews/article/comment/366/0001067643
# https://n.news.naver.com/mnews/article/018/0005982461 [사고]스테이블코인 vs CBDC…디지털금융 대세는 어디로?
# https://n.news.naver.com/mnews/article/comment/018/0005982461
# https://n.news.naver.com/mnews/article/021/0002701758 폐암 면역치료 새 전략 찾았다…면역항암 막는 핵심인자 최초로 발견
# https://n.news.naver.com/mnews/article/comment/021/0002701758
# https://n.news.naver.com/mnews/article/092/0002369817 "갤럭시S26 울트라, 카메라 사양 등 전작과 큰 변화 없다"
# https://n.news.naver.com/mnews/article/comment/092/0002369817
# https://n.news.naver.com/mnews/article/092/0002369816 구영배 "위시 살려야" 주장에 피해자들 분통…"차라리 처벌 받아라"
# https://n.news.naver.com/mnews/article/comment/092/0002369816
# https://n.news.naver.com/mnews/article/092/0002369815 관세 폭탄에 스마트폰 공장 美로 옮긴다?…"가능성 희박"
# https://n.news.naver.com/mnews/article/comment/092/0002369815
# https://n.news.naver.com/mnews/article/015/0005116508 전국에 딱 500대만 풀린다…'한정판 갤럭시S25'의 정체
# https://n.news.naver.com/mnews/article/comment/015/0005116508
# https://n.news.naver.com/mnews/article/030/0003301337 [6G 코리아] ④ 이통3사, AI-RAN 시장 개척 주도
# https://n.news.naver.com/mnews/article/comment/030/0003301337
# https://n.news.naver.com/mnews/article/015/0005116502 한바이오 "모유두세포로 탈모 정복하겠다"
# https://n.news.naver.com/mnews/article/comment/015/0005116502
# https://n.news.naver.com/mnews/article/293/0000065879 뤼튼, 감정 교류도 하는 'AI 비서' 낸다
# https://n.news.naver.com/mnews/article/comment/293/0000065879
# https://n.news.naver.com/mnews/article/092/0002369813 온라인서 예금토큰 결제 지연…9일부터 순차적으로 진행
# https://n.news.naver.com/mnews/article/comment/092/0002369813
# https://n.news.naver.com/mnews/article/030/0003301326 법인 가상자산 투자 허용, 금융 생태계 지각변동 예고...우덕수 블록데몬 아시아 대표 “기관 대상 상품 본격화”
# https://n.news.naver.com/mnews/article/comment/030/0003301326
# https://n.news.naver.com/mnews/article/366/0001067631 美와 AI 격차 좁힌 中…한국은 AI 투자 줄어
# https://n.news.naver.com/mnews/article/comment/366/0001067631
# https://n.news.naver.com/mnews/article/030/0003301320 LS전선, 대한전선 상대 특허 최종 승소…양측 상고 포기
# https://n.news.naver.com/mnews/article/comment/030/0003301320
# https://n.news.naver.com/mnews/article/023/0003898272 사람 태워 산속 누빈다... 늑대 닮은 日 4족보행 로봇 공개
# https://n.news.naver.com/mnews/article/comment/023/0003898272
# https://n.news.naver.com/mnews/article/030/0003301315 삼성전자 시장예상 뛰어넘은 1분기 실적...매출 79조·영업익 6.6조
# https://n.news.naver.com/mnews/article/comment/030/0003301315
# https://n.news.naver.com/mnews/article/421/0008180285 '2인 체제' 방통위 논란 여전…이대로면 '줄소송' 가능성
# https://n.news.naver.com/mnews/article/comment/421/0008180285
# https://n.news.naver.com/mnews/article/015/0005116490 "영락없는 자녀 목소린데"…AI 보이스피싱, AI로 방지
# https://n.news.naver.com/mnews/article/comment/015/0005116490
# https://n.news.naver.com/mnews/article/138/0002194264 DDR5 가격 불 붙인 中 CXMT…삼성⋅SK '반사이익' 장기화 기대 [소부장반차장]
# https://n.news.naver.com/mnews/article/comment/138/0002194264
# https://n.news.naver.com/mnews/article/029/0002946687 100년간 해킹 불가… 팬시코인, 세계 최초 `양자암호내성 블록체인 지갑` 승인
# https://n.news.naver.com/mnews/article/comment/029/0002946687
# https://n.news.naver.com/mnews/article/030/0003301302 중소 알뜰폰 '저가형'에 대기업 알뜰폰, '이색 요금제'
# https://n.news.naver.com/mnews/article/comment/030/0003301302
# https://n.news.naver.com/mnews/article/421/0008180265 질병청, 국내 기술로 최초 단백질 탄저백신 개발…'26년 결실'(종합)
# https://n.news.naver.com/mnews/article/comment/421/0008180265
# https://n.news.naver.com/mnews/article/030/0003301301 [IT구루 간담회] AI 에이전트 등 응용분야 육성 전략, 인재양성 패러다임 전환해야
# https://n.news.naver.com/mnews/article/comment/030/0003301301
# https://n.news.naver.com/mnews/article/277/0005574594 "가구 배치, 옷 코디도 도와준다"…제미나이 라이브 갤S25 적용
# https://n.news.naver.com/mnews/article/comment/277/0005574594
# https://n.news.naver.com/mnews/article/030/0003301290 매그나칩, DDI 사업 청산…임직원 해고 통보
# https://n.news.naver.com/mnews/article/comment/030/0003301290
# https://n.news.naver.com/mnews/article/009/0005472676 상금 30억원 내건 슈퍼센트, ‘제4회 슈퍼센트 게임 챌린지’ 개최
# https://n.news.naver.com/mnews/article/comment/009/0005472676
# https://n.news.naver.com/mnews/article/584/0000031781 항생제 내성 슈퍼박테리아, 나노입자 결합시켜 열로 제거한다
# https://n.news.naver.com/mnews/article/comment/584/0000031781
# https://n.news.naver.com/mnews/article/366/0001067619 MS가 주목한 韓 스타트업 뤼튼 “전 국민 맞춤형 AI 시대 만든다”
# https://n.news.naver.com/mnews/article/comment/366/0001067619

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

section_dict = {
    100: "정치",
    101: "경제",
    102: "사회",
    103: "생활/문화",
    104: "세계",
    105: "IT/과학",
}

# def print_news(sid, section):  # print_new(103,'생활/문화')
# req_param = {"sid": sid}
def print_news(sid):
    section = section_dict[sid]
    #
    url = "https://news.naver.com/section/{sid}".format(**req_param)
    print(f"=========> {url} {section} 뉴스 <===========")

    req_header = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36"
    }

    # requests 의 get() 함수 호출하기
    res = requests.get(url, headers=req_header)
    print(res)
    print(type(res))
    print(res.status_code, res.ok)

    # 응답(response)이 OK 이면
    if res.ok:
        # 응답 (response)에서 text 추출
        html = res.text
        # print(html)
        # BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, "html.parser")
        print(soup)
        # CSS 선택자
        # <div class='sa_text'><a></a></div?
        print(len(soup.select("div.sa_text a[href*='mnews/article']")))
        # print(soup.select("div.sa_text a[href*='mnews/article']"))
        a_tag_list = soup.select("div.sa_text a[href*='mnews/article']")
        print(type(a_tag_list))  # ResultSet
        for a_tag in a_tag_list:
            # print(type(a_tag))
            title = a_tag.text.strip()
            # href 속성에 값을 가져온다.
            link = a_tag["href"]
            print(link, title)

        # <a> 태그 리스트 순회하기
    else:
        # 응답(response)이 Error 이면 status code 출력
        print(f"에러 코드 = {res.status_code}")

    # print_news(103,section_dict[103])
    # 함수호출
print_news(101)

# select ('ul.list_newssheadlin2 li') [<li></li>]

# <ul> 
 # <li>
  # <a href="링크">
   #<div class="cont_thum">
    #<strong class="tit_txt">뉴스제목
    
# for li_tag select('ul.list_newsheadline2 li')
    #a_tag = li_tag.find('a')
    #link = a_tag['href']
    
    #strong_tag = li_tag.select_one('div.cont_thum strong_tit_txt')
    #title = strong_tag.text
    #response encoding 을 utf-8
# Out:
# =========> https://news.naver.com/section/105 경제 뉴스 <===========
# <Response [200]>
# <class 'requests.models.Response'>
# 200 True
# <!DOCTYPE html>
#
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="IT/과학 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/section/105" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="IT/과학 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공" name="twitter:description"/>
# <title>IT/과학 : 네이버 뉴스</title>
# <link href="https://static-nnews.pstatic.net/css/min/20250403/news.css" rel="stylesheet"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" rel="apple-touch-icon-precomposed" size="72x72"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" rel="apple-touch-icon-precomposed" size="96x96"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" rel="apple-touch-icon-precomposed" size="144x144"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed" size="192x192"/>
# <script>
# 			var bSupportedIntersectionObserver = "IntersectionObserver" in window;
# 		</script>
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# <script>
# 			var g_ssc = nsc = "news.v3_sec";
# 			var g_default_area = "itn";
#
# 			var svr = "one-service-h-20250403-250407-211653-6878c6d4-zdp6g";
# 			var nelo = {
# 				name : "one-front",
# 				url : "https://kr-col-ext.nelo.navercorp.com/_store",
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "";
# 			var layoutName = "section_home";
# 			var layoutType = "section";
# 			var isAvailableDarkMode = false;
# 			var moduleLoadStatus = -1;
#
# 			var article = {
#
# 				officeId: "",
# 				articleId: "",
# 				sectionId : "",
# 				gdid: "",
# 				type: "",
# 				sectionInfo: {
# 					firstSection: "",
# 					secondSection: "",
# 					thirdSection: ""
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: false,
# 				isPressHome: false,
# 				name : "",
# 				category : ""
# 			};
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newslist",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: false,
# 					hasSid1: true
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: true,
# 					hasSid1: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
# 					var hasSid1 = adInfo.hasSid1;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "shome";
# 					}
# 					if (hasSid1 == true) {
# 						customParam.sid1 = "105";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# <script src="https://static-nnews.pstatic.net/js/min/20250403b/common.min.js"></script>
# </link></meta></head>
# <body class="n_news_mnews fs1 as_mp_layout as_section_home">
# <div class="end_container">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <header class="as_gnb_mnews as_type_section" role="banner">
# <div class="header_inner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link _LINK" data-clk="gnb.naver" data-pc-url="https://www.naver.com/" data-url="https://m.naver.com/" href="https://m.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a class="_LINK" data-clk="gnb.news" data-pc-url="https://news.naver.com/" data-url="https://m.news.naver.com" href="https://m.news.naver.com"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.entertain" data-pc-url="https://entertain.naver.com/home" data-url="https://m.entertain.naver.com" href="https://m.entertain.naver.com">
# <span class="Nicon_family Nicon_entertain">엔터</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.sports" data-pc-url="https://sports.news.naver.com/index" data-url="https://m.sports.naver.com" href="https://m.sports.naver.com">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.weather" href="https://weather.naver.com">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.premium" href="https://contents.premium.naver.com">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho" href="javascript:;"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb" data-scroll-fixed="true" id="_LNB_PARENT_WRAP" style="z-index:3000;">
# <div class="Nlnb_menu Ntype_scroll" id="_LNB_WRAP">
# <div class="Nlnb_menu_inner" id="_LNB">
# <ul class="Nlnb_menu_list" role="tablist">
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.press" href="https://news.naver.com/" role="tab"><span class="Nitem_link_menu">언론사별</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.pol" href="https://news.naver.com/section/100" role="tab"><span class="Nitem_link_menu">정치</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.eco" href="https://news.naver.com/section/101" role="tab"><span class="Nitem_link_menu">경제</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.soc" href="https://news.naver.com/section/102" role="tab"><span class="Nitem_link_menu">사회</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.lif" href="https://news.naver.com/section/103" role="tab"><span class="Nitem_link_menu">생활/문화</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM is_active" role="presentation">
# <a aria-selected="true" class="Nitem_link" data-clk="lnb.it" href="https://news.naver.com/section/105" role="tab"><span class="Nitem_link_menu">IT/과학</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.wor" href="https://news.naver.com/section/104" role="tab"><span class="Nitem_link_menu">세계</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.rank" href="https://news.naver.com/main/ranking/popularDay.naver?mid=etc&amp;sid1=111" role="tab"><span class="Nitem_link_menu">랭킹</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.paper" href="https://news.naver.com/newspaper/home" role="tab"><span class="Nitem_link_menu">신문보기</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.opi" href="https://news.naver.com/main/opinion/home.naver" role="tab"><span class="Nitem_link_menu">오피니언</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.tv" href="https://news.naver.com/main/tv/index.naver?mid=tvh" role="tab"><span class="Nitem_link_menu">TV</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.fact" href="https://news.naver.com/main/factcheck/main.naver" role="tab"><span class="Nitem_link_menu">팩트체크</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.algo" href="https://media.naver.com/algorithm" role="tab"><span class="Nitem_link_menu">알고리즘 안내</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.correct" href="https://news.naver.com/ombudsman/errorArticleList" role="tab"><span class="Nitem_link_menu">정정보도 모음</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <hr/>
# <script>
# 	var svt = "20250408165545.919";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var nilNtmUrl = "https://ntm.pstatic.net/scripts/ntm_b7032129a433.js";
#
# 	var envPhase = "production";
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# 	var gnb_item_hide_option = 128;
#
# 	var isDegradeMode = false;
# 	var isDegradeN2Mode = false;
# </script>
# <div class="ct_wrap" id="ct_wrap">
# <div class="ct_lnb">
# <div class="ct_lnb_inner">
# <strong class="ct_lnb_date">04.08(화)</strong>
# <ul class="ct_lnb_side">
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.allmedia" href="https://news.naver.com/main/officeList.naver">전체 언론사</a>
# </li>
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.newsstand" href="https://newsstand.naver.com/" target="_blank">뉴스스탠드</a>
# </li>
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.library" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank">라이브러리</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="ct_scroll_wrapper">
# <div class="column0">
# <div class="ct_snb">
# <h2 class="ct_snb_h2">
# <a class="ct_snb_h2_a" data-clk="lmn_itn.home" href="/section/105">IT/과학</a>
# </h2>
# <ul class="ct_snb_nav">
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="1" href="/breakingnews/section/105/731">모바일</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="2" href="/breakingnews/section/105/226">인터넷/SNS</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="3" href="/breakingnews/section/105/227">통신/뉴미디어</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="4" href="/breakingnews/section/105/230">IT 일반</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="5" href="/breakingnews/section/105/732">보안/해킹</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="6" href="/breakingnews/section/105/283">컴퓨터</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="7" href="/breakingnews/section/105/229">게임/리뷰</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="8" href="/breakingnews/section/105/228">과학 일반</a>
# </li>
# </ul>
# <div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <a data-clk="lmn_itn.pmb" data-rank="1" href="https://media.naver.com/algorithm">
# <img alt="AI 뉴스 알고리즘 안내" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/10/184436024_banner_left.png" height="74" style="display: none;" width="71"/>
# </a>
# </div>
# <div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <a data-clk="lmn_itn.pmb" data-rank="2" href="https://contents.premium.naver.com/">
# <img alt="프리미엄콘텐츠" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" height="74" style="display: none;" width="71"/>
# </a>
# </div>
# </div>
# </div>
# <div class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT" id="newsct" role="main"><div class="section_component as_section_headline _PERSIST_CONTENT" data-persist="2_sectionHeadline">
# <div class="section_article as_headline _TEMPLATE" data-template-id="SECTION_HEADLINE">
# <div class="sa_head">
# <span class="sa_head_inner">
# <a class="sa_head_link _TOGGLE" data-classvalue="is_hidden" data-clk="guide" data-target="_SECTION_HEADLINE_INFO_6dov2" href="#">헤드라인 뉴스 <i class="sa_head_icon">안내</i></a>
# </span>
# <div class="sa_head_layer is_hidden" id="_SECTION_HEADLINE_INFO_6dov2">
# <p class="sa_head_layer_p">각 헤드라인의 기사와 배열 순서는 개인화를 반영해 추천되며, 기사묶음의 대표 기사는 구독 언론사 중심으로 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 자동 추출됩니다.</p>
# <a class="sa_head_layer_go" href="https://media.naver.com/algorithm">알고리즘 자세히 보기</a>
# <div class="sa_head_layer_close">
# <button class="_TOGGLE" data-classvalue="is_hidden" data-target="_SECTION_HEADLINE_INFO_6dov2" type="button">닫기</button>
# </div>
# </div>
# </div>
# <ul class="sa_list" id="_SECTION_HEADLINE_LIST_6dov2">
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="8800010E_000000000000000002454308" data-imp-index="1" data-imp-url="https://n.news.naver.com/mnews/article/016/0002454308" href="https://n.news.naver.com/mnews/article/016/0002454308">
# <img alt="“전국민에 맞는 AI 5000만개 보급할 것”…뤼튼, ‘생활형 AI’ 시대 연다" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/016/2025/04/08/2454308.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="8800010E_000000000000000002454308" data-imp-index="1" data-imp-url="https://n.news.naver.com/mnews/article/016/0002454308" href="https://n.news.naver.com/mnews/article/016/0002454308">
# <strong class="sa_text_strong">“전국민에 맞는 AI 5000만개 보급할 것”…뤼튼, ‘생활형 AI’ 시대 연다</strong>
# </a>
# <div class="sa_text_lede">프레스 컨퍼런스 2025서 ‘뤼튼 3.0’ 공개 일상에서 쉽게 사용하는 ‘생활형 AI’ 진화 맞춤화된 ‘AI 서포터’가 감정 교류·업무 지원 수익 창출 기능 도입…금융·커머스로 확대 이세영 뤼튼테크놀로지스 대표. [</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">헤럴드경제</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news016,0002454308" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/016/0002454308" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202504081210_00001805/section/105?oid=016&amp;aid=0002454308">
# <span class="sa_text_cluster_num">23</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000D8_000000000000000015317061" data-imp-index="2" data-imp-url="https://n.news.naver.com/mnews/article/001/0015317061" href="https://n.news.naver.com/mnews/article/001/0015317061">
# <img alt="스팸문자 사전 차단 '엑스레이 서비스' 9일 시범 도입" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/001/2025/04/08/15317061.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000D8_000000000000000015317061" data-imp-index="2" data-imp-url="https://n.news.naver.com/mnews/article/001/0015317061" href="https://n.news.naver.com/mnews/article/001/0015317061">
# <strong class="sa_text_strong">스팸문자 사전 차단 '엑스레이 서비스' 9일 시범 도입</strong>
# </a>
# <div class="sa_text_lede">과학기술정보통신부와 한국인터넷진흥원(KISA)은 스미싱 등 악성 문자를 발송 단계에서부터 차단할 수 있는 '엑스레이 사전 차단 서비스'를 9일 오전 9시부터 시범 운영한다고 8일 밝혔다. 악성 문자 속의 스미싱 유도</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">연합뉴스</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news001,0015317061" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/001/0015317061" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202504081210_00000024/section/105?oid=001&amp;aid=0015317061">
# <span class="sa_text_cluster_num">17</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000C2_000000000000000005177334" data-imp-index="3" data-imp-url="https://n.news.naver.com/mnews/article/008/0005177334" href="https://n.news.naver.com/mnews/article/008/0005177334">
# <img alt="금융과 통신의 결합…기업은행, SKT와 AI로 보이스피싱 막는다" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/008/2025/04/08/5177334.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000C2_000000000000000005177334" data-imp-index="3" data-imp-url="https://n.news.naver.com/mnews/article/008/0005177334" href="https://n.news.naver.com/mnews/article/008/0005177334">
# <strong class="sa_text_strong">금융과 통신의 결합…기업은행, SKT와 AI로 보이스피싱 막는다</strong>
# </a>
# <div class="sa_text_lede">IBK기업은행이 8일 SKT(SK텔레콤)와 손잡고 금융과 통신 정보를 연계한 'AI(인공지능) 보이스피싱 피해·탐지 서비스'를 시작했다. 'AI 보이스피싱 피해·탐지 서비스'는 SKT가 제공하는 금융권 고객보호 강화</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">머니투데이</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news008,0005177334" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/008/0005177334" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202504061540_00000172/section/105?oid=008&amp;aid=0005177334">
# <span class="sa_text_cluster_num">47</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000D8_000000000000000015316436" data-imp-index="4" data-imp-url="https://n.news.naver.com/mnews/article/001/0015316436" href="https://n.news.naver.com/mnews/article/001/0015316436">
# <img alt="신제품 갤럭시 S25 효과에…삼성전자 MX 1분기 실적 개선" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/001/2025/04/08/15316436.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000D8_000000000000000015316436" data-imp-index="4" data-imp-url="https://n.news.naver.com/mnews/article/001/0015316436" href="https://n.news.naver.com/mnews/article/001/0015316436">
# <strong class="sa_text_strong">신제품 갤럭시 S25 효과에…삼성전자 MX 1분기 실적 개선</strong>
# </a>
# <div class="sa_text_lede">역대 최다 사전 판매량 기록한 점 주효했을 듯 증권가, 관세로 인해 2분기는 실적 하향 예상 삼성전자가 지난 1분기 시장 기대치를 웃도는 실적을 낸 데에는 갤럭시 S25 시리즈를 담당하는 모바일경험(MX) 사업부의 </div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">연합뉴스</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news001,0015316436" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/001/0015316436" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202504081010_00000078/section/105?oid=001&amp;aid=0015316436">
# <span class="sa_text_cluster_num">8</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000E7_000000000000000005982179" data-imp-index="5" data-imp-url="https://n.news.naver.com/mnews/article/018/0005982179" href="https://n.news.naver.com/mnews/article/018/0005982179">
# <img alt='신세계I&amp;C, AI 무인매장 솔루션 출시…"리테일테크 사업 확대"' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/018/2025/04/08/5982179.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000E7_000000000000000005982179" data-imp-index="5" data-imp-url="https://n.news.naver.com/mnews/article/018/0005982179" href="https://n.news.naver.com/mnews/article/018/0005982179">
# <strong class="sa_text_strong">신세계I&amp;C, AI 무인매장 솔루션 출시…"리테일테크 사업 확대"</strong>
# </a>
# <div class="sa_text_lede">신세계I&amp;C(신세계(004170)아이앤씨)는 유통 산업에 특화된 인공지능(AI) 모델 ‘스파로스 AI 비전’ 기반의 솔루션 라인업을 확대하고 AI 전환(AX) 사업 본격화에 나선다고 8일 밝혔다. 신세계I</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">이데일리</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news018,0005982179" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/018/0005982179" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202504080750_00000002/section/105?oid=018&amp;aid=0005982179">
# <span class="sa_text_cluster_num">8</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="section_component as_section_series _PERSIST_CONTENT" data-persist="3_sectionSeries">
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# <div class="ss_head">
# <div class="ss_head_inner">
# <a class="ss_head_link" data-clk="sert" href="https://news.naver.com/hotissue/main?sid1=163&amp;cid=2000002">
# <span class="ss_head_go">연재보기</span>
# <h2 class="ss_head_topic">미래on</h2>
# </a>
# </div>
# </div>
# <div class="ss_body">
# <ul class="ss_list">
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="08138263_000000000000000008178889" data-imp-index="gzqwk" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/421/0008178889?type=series&amp;cid=2000002" href="https://n.news.naver.com/mnews/hotissue/article/421/0008178889?type=series&amp;cid=2000002">
# <img alt="AI 데이터센터 발목잡는 GPU 발열…액침냉각이 열쇠" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/421/2025/04/08/8178889.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="08138263_000000000000000008178889" data-imp-index="gzqwk" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/421/0008178889?type=series&amp;cid=2000002" href="https://n.news.naver.com/mnews/hotissue/article/421/0008178889?type=series&amp;cid=2000002">AI 데이터센터 발목잡는 GPU 발열…액침냉각이 열쇠</a>
# <div class="ss_text_lede">기술·사회·산업·문화 전반의 변화가 가속화하고 있다. 산업·문화 혁신과 사회·인구 구조 변화 등 여러 요인이 유기적으로 맞물린 현상이다. 다가오는 시대에 성공적으로 대처하려면 현재를 진단하고 미래를 가늠해 보는 지혜</div>
# <div class="ss_text_info">
# <div class="ss_text_press">뉴스1</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news421,0008178889" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/421/0008178889" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="08138263_000000000000000008164752" data-imp-index="c623o" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/421/0008164752?type=series&amp;cid=2000002" href="https://n.news.naver.com/mnews/hotissue/article/421/0008164752?type=series&amp;cid=2000002">
# <img alt="영상 픽셀 속 혈류 분석…딥페이크 잡는 '페이크 캐처'" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/421/2025/04/01/8164752.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="08138263_000000000000000008164752" data-imp-index="c623o" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/421/0008164752?type=series&amp;cid=2000002" href="https://n.news.naver.com/mnews/hotissue/article/421/0008164752?type=series&amp;cid=2000002">영상 픽셀 속 혈류 분석…딥페이크 잡는 '페이크 캐처'</a>
# <div class="ss_text_lede">기술·사회·산업·문화 전반의 변화가 가속화하고 있다. 산업·문화 혁신과 사회·인구 구조 변화 등 여러 요인이 유기적으로 맞물린 현상이다. 다가오는 시대에 성공적으로 대처하려면 현재를 진단하고 미래를 가늠해 보는 지혜</div>
# <div class="ss_text_info">
# <div class="ss_text_press">뉴스1</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news421,0008164752" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/421/0008164752" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="08138263_000000000000000008149696" data-imp-index="53u9b" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/421/0008149696?type=series&amp;cid=2000002" href="https://n.news.naver.com/mnews/hotissue/article/421/0008149696?type=series&amp;cid=2000002">
# <img alt="AI가 도시 두뇌 된다…'스마트시티' 통합 혁신 가속" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/421/2025/03/25/8149696.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="08138263_000000000000000008149696" data-imp-index="53u9b" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/421/0008149696?type=series&amp;cid=2000002" href="https://n.news.naver.com/mnews/hotissue/article/421/0008149696?type=series&amp;cid=2000002">AI가 도시 두뇌 된다…'스마트시티' 통합 혁신 가속</a>
# <div class="ss_text_lede">기술·사회·산업·문화 전반의 변화가 가속화하고 있다. 산업·문화 혁신과 사회·인구 구조 변화 등 여러 요인이 유기적으로 맞물린 현상이다. 다가오는 시대에 성공적으로 대처하려면 현재를 진단하고 미래를 가늠해 보는 지혜</div>
# <div class="ss_text_info">
# <div class="ss_text_press">뉴스1</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news421,0008149696" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/421/0008149696" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="08138263_000000000000000008135058" data-imp-index="yz3e5" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/421/0008135058?type=series&amp;cid=2000002" href="https://n.news.naver.com/mnews/hotissue/article/421/0008135058?type=series&amp;cid=2000002">
# <img alt="더 밝아질까, 어두워질까…밤하늘의 모습은" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/421/2025/03/18/8135058.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="08138263_000000000000000008135058" data-imp-index="yz3e5" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/421/0008135058?type=series&amp;cid=2000002" href="https://n.news.naver.com/mnews/hotissue/article/421/0008135058?type=series&amp;cid=2000002">더 밝아질까, 어두워질까…밤하늘의 모습은</a>
# <div class="ss_text_lede">기술·사회·산업·문화 전반의 변화가 가속화하고 있다. 산업·문화 혁신과 사회·인구 구조 변화 등 여러 요인이 유기적으로 맞물린 현상이다. 다가오는 시대에 성공적으로 대처하려면 현재를 진단하고 미래를 가늠해 보는 지혜</div>
# <div class="ss_text_info">
# <div class="ss_text_press">뉴스1</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news421,0008135058" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/421/0008135058" style="display: none;"></a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# <div class="ss_head">
# <div class="ss_head_inner">
# <a class="ss_head_link" data-clk="sert" href="https://news.naver.com/hotissue/main?sid1=163&amp;cid=2002197">
# <span class="ss_head_go">연재보기</span>
# <h2 class="ss_head_topic">오늘의 천체사진</h2>
# </a>
# </div>
# </div>
# <div class="ss_body">
# <ul class="ss_list">
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="88127058_000000000000000001067666" data-imp-index="yxaed" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/366/0001067666?type=series&amp;cid=2002197" href="https://n.news.naver.com/mnews/hotissue/article/366/0001067666?type=series&amp;cid=2002197">
# <img alt="푸른 빛의 플레이아데스 성단과 달" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/366/2025/04/08/1067666.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="88127058_000000000000000001067666" data-imp-index="yxaed" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/366/0001067666?type=series&amp;cid=2002197" href="https://n.news.naver.com/mnews/hotissue/article/366/0001067666?type=series&amp;cid=2002197">푸른 빛의 플레이아데스 성단과 달</a>
# <div class="ss_text_lede">달이 플레이아데스 성단을 지나고 있다. 플레이아데스 성단은 지구로부터 497광년(光年·1광년은 빛이 1년 가는 거리로 약 9조4600억㎞) 떨어진 산개 성단이다. 젊은 별 여러 개가 모인 것을 산개 성단이라고 한다.</div>
# <div class="ss_text_info">
# <div class="ss_text_press">조선비즈</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news366,0001067666" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/366/0001067666" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="88127058_000000000000000001067364" data-imp-index="tf6hx" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/366/0001067364?type=series&amp;cid=2002197" href="https://n.news.naver.com/mnews/hotissue/article/366/0001067364?type=series&amp;cid=2002197">
# <img alt="NGC 4414: 솜털같은 나선은하" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/366/2025/04/07/1067364.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="88127058_000000000000000001067364" data-imp-index="tf6hx" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/366/0001067364?type=series&amp;cid=2002197" href="https://n.news.naver.com/mnews/hotissue/article/366/0001067364?type=series&amp;cid=2002197">NGC 4414: 솜털같은 나선은하</a>
# <div class="ss_text_lede">솜털같은 나선은하는 얼마나 많은 질량을 숨기고 있을까. 이 질문에 답하기 위해 허블 우주망원경이 촬영한 나선은하 NGC 4414의 이미지가 공개됐다. 솜털같은 나선은하는 뚜렷한 나선팔이 없는 형태의 은하로 매우 흔한</div>
# <div class="ss_text_info">
# <div class="ss_text_press">조선비즈</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news366,0001067364" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/366/0001067364" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="88127058_000000000000000001067152" data-imp-index="adxl2" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/366/0001067152?type=series&amp;cid=2002197" href="https://n.news.naver.com/mnews/hotissue/article/366/0001067152?type=series&amp;cid=2002197">
# <img alt="달 지진" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/366/2025/04/06/1067152.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="88127058_000000000000000001067152" data-imp-index="adxl2" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/366/0001067152?type=series&amp;cid=2002197" href="https://n.news.naver.com/mnews/hotissue/article/366/0001067152?type=series&amp;cid=2002197">달 지진</a>
# <div class="ss_text_lede">1969년 7월, ‘아폴로 11호’ 우주비행사 닐 암스트롱과 버즈 올드린이 달에 첫발을 내딛고 미국 성조기를 꽂았다. 사진은 당시 버즈 올드린이 달 지진계 옆에 서 있는 모습이다. 미국 항공우주국(NASA)에 따르면</div>
# <div class="ss_text_info">
# <div class="ss_text_press">조선비즈</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news366,0001067152" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/366/0001067152" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="88127058_000000000000000001066836" data-imp-index="p8p1w" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/366/0001066836?type=series&amp;cid=2002197" href="https://n.news.naver.com/mnews/hotissue/article/366/0001066836?type=series&amp;cid=2002197">
# <img alt="사자자리의 ‘힉슨 44 은하단’" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/366/2025/04/04/1066836.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="88127058_000000000000000001066836" data-imp-index="p8p1w" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/366/0001066836?type=series&amp;cid=2002197" href="https://n.news.naver.com/mnews/hotissue/article/366/0001066836?type=series&amp;cid=2002197">사자자리의 ‘힉슨 44 은하단’</a>
# <div class="ss_text_lede">1982년 캐나다 천문학자 폴 힉슨(Paul Hickson)이 발견한 100여개의 소형 은하 그룹은 현재 ‘힉슨 소형 그룹’으로 불린다. 사진에서 보이는 4개의 은하가 바로 그 중 하나인 ‘힉슨 44 은하단’이다. </div>
# <div class="ss_text_info">
# <div class="ss_text_press">조선비즈</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news366,0001066836" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/366/0001066836" style="display: none;"></a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="r_group_comp ad_box _da_banner _PERSIST_HEIGHT is_border_none" data-persist="1_ad">
# <div class="ad_area _AD_WRAP" data-article="false" data-mobileonly="false" data-sync="false" data-unitid="p_news_newslist" id="nmap_c____1"></div>
# </div>
# <div class="section_latest">
# <div class="section_component as_section_article_list _PERSIST_CONTENT" data-persist="SECTION_ARTICLE_LIST">
# <div class="section_latest_article _CONTENT_LIST _PERSIST_META" data-cluid="" data-cursor="20250408150356" data-cursor-name="next" data-date="" data-has-next="true" data-nclk="airscont" data-page-no="1" data-persist="SECTION_ARTICLE_LIST_META" data-persist-meta-restore="true" data-sid="105" data-sid2="" data-template="SECTION_ARTICLE_LIST">
# <div class="section_article _TEMPLATE" data-template-id="SECTION_ARTICLE_LIST">
# <ul class="sa_list">
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"SDeXYIfuGaI5bxZs"}}' data-gdid="8817ca11_000000000000000000031788" data-imp-url="https://n.news.naver.com/mnews/article/584/0000031788" data-rank="1" href="https://n.news.naver.com/mnews/article/584/0000031788">
# <img alt="'왕좌의 게임' 늑대 부활…1만2500년전 멸종 '다이어울프' 복원" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/584/2025/04/08/31788.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"SDeXYIfuGaI5bxZs"}}' data-gdid="8817ca11_000000000000000000031788" data-imp-url="https://n.news.naver.com/mnews/article/584/0000031788" data-rank="1" href="https://n.news.naver.com/mnews/article/584/0000031788">
# <strong class="sa_text_strong">'왕좌의 게임' 늑대 부활…1만2500년전 멸종 '다이어울프' 복원</strong>
# </a>
# <div class="sa_text_lede">생명공학 기술로 멸종 동물을 복원하는 미국 기업 '콜로설 바이오사이언시스(콜로설)'가 아메리카 대륙에 살다가 멸종한 늑대 종인 다이어울프(학명 Aenocyon dirus)와 비슷한 늑대 3마리를 탄생시켜 공개했다. </div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">동아사이언스</div>
# <div class="sa_text_datetime is_recent">
# <b>12분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news584,0000031788" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/584/0000031788" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"SDeXYIfuGaI5bxZs"}}' data-gdid="8800011E_000000000000000002369853" data-imp-url="https://n.news.naver.com/mnews/article/092/0002369853" data-rank="2" href="https://n.news.naver.com/mnews/article/092/0002369853">
# <img alt="뉴엔AI, 英 FT가 뽑은 고성장 '500대 기업' 등극…IPO로 성장 정점 찍나" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/092/2025/04/08/2369853.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"SDeXYIfuGaI5bxZs"}}' data-gdid="8800011E_000000000000000002369853" data-imp-url="https://n.news.naver.com/mnews/article/092/0002369853" data-rank="2" href="https://n.news.naver.com/mnews/article/092/0002369853">
# <strong class="sa_text_strong">뉴엔AI, 英 FT가 뽑은 고성장 '500대 기업' 등극…IPO로 성장 정점 찍나</strong>
# </a>
# <div class="sa_text_lede">파이낸셜타임즈(FT)가 뉴엔AI를 2년 연속 '아시아·태평양 고성장 기업'으로 선정했다. 생성형 인공지능(AI) 기술력을 기반으로 한 회사의 글로벌 경쟁력이 공신력 있는 외신을 통해 공식 인증된 셈이다. 뉴엔AI는 </div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">지디넷코리아</div>
# <div class="sa_text_datetime is_recent">
# <b>14분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news092,0002369853" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/092/0002369853" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"SDeXYIfuGaI5bxZs"}}' data-gdid="880000D8_000000000000000015318051" data-imp-url="https://n.news.naver.com/mnews/article/001/0015318051" data-rank="3" href="https://n.news.naver.com/mnews/article/001/0015318051">
# <img alt="[마켓톺] 관세전쟁에 빛바랜 삼성전자의 호실적…반등의 조건은" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/001/2025/04/08/15318051.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"SDeXYIfuGaI5bxZs"}}' data-gdid="880000D8_000000000000000015318051" data-imp-url="https://n.news.naver.com/mnews/article/001/0015318051" data-rank="3" href="https://n.news.naver.com/mnews/article/001/0015318051">
# <strong class="sa_text_strong">[마켓톺] 관세전쟁에 빛바랜 삼성전자의 호실적…반등의 조건은</strong>
# </a>
# <div class="sa_text_lede">반도체株 반등에도 외국인·기관 매도세에 삼전 오름폭 4%→0.6% 축소 관세전쟁 장기화에 추가 변동성 우려…"2분기부터 관련 영향 확인될 것" 삼성전자가 8일 예상보다 좋은 1분기 실적을 내놓으면 주가가 반등에 성공</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">연합뉴스</div>
# <div class="sa_text_datetime is_recent">
# <b>20분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news001,0015318051" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/001/0015318051" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"SDeXYIfuGaI5bxZs"}}' data-gdid="88000103_000000000000000002739882" data-imp-url="https://n.news.naver.com/mnews/article/028/0002739882" data-rank="4" href="https://n.news.naver.com/mnews/article/028/0002739882">
# <img alt="한국계 우주비행사 태운 러 우주선, 우주정거장 향해 발사" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/028/2025/04/08/2739882.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"SDeXYIfuGaI5bxZs"}}' data-gdid="88000103_000000000000000002739882" data-imp-url="https://n.news.naver.com/mnews/article/028/0002739882" data-rank="4" href="https://n.news.naver.com/mnews/article/028/0002739882">
# <strong class="sa_text_strong">한국계 우주비행사 태운 러 우주선, 우주정거장 향해 발사</strong>
# </a>
# <div class="sa_text_lede">한국계 미국인인 미국항공우주국(나사) 우주비행사 조니 김이 국제우주정거장(ISS) 임무 수행을 위해 지구를 출발했다. 한국계 우주비행사가 우주정거장 승무원으로 활동하는 건 이번이 처음이다. 러시아 연방우주국(로스코스</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">한겨레</div>
# <div class="sa_text_datetime is_recent">
# <b>21분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news028,0002739882" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/028/0002739882" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# ...
# <script class="_MY_FEED_CANCEL_MODAL_TEMPLATE" type="x-tmpl-mustache">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 연재는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_ALL"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_OS"></div>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="" onerror="this.outerHTML='<span class=&quot;no_image&quot;></span>'">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_OS" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="napp_notify_notice">
# 	<div class="napp_notify_info_area">
# 		<strong class="napp_notify_title">네이버 앱 푸시알림이 꺼져있어요.</strong>
# 		<div class="napp_notify_desc_box">
# 			<p class="napp_notify_desc1">네이버 앱 알림켜기 &gt; 알림탭 &gt; 알림허용</p>
# 			<p class="napp_notify_desc2">버튼을 눌러 앱 알림 설정을 켜주세요.</p>
# 		</div>
# 	</div>
# 	<div class="napp_notify_button_area">
# 		<button type="button" class="napp_notify_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}.osnotoff">닫기</button>
# 		<button type="button" class="napp_notify_btn highlight _MODAL_LAYER_POSITIVE _NAPP_NOTIFY_COMPLETE" data-clk="{{nclk}}.osnoton">네이버 앱 알림 켜기</button>
# 	</div>
# </div>
# </div>
# </script>
# <div id="_MODAL_DIALOG_WRAP" style="display: none;"></div>
# <script class="_MODAL_DIALOG_TEMPLATE" type="x-tmpl-mustache">
# <div class="nds_dialog_dimmed">
# 	<div class="nds_dialog_basic">
# 		<div class="nds_dialog_content">
# 			{{#isTextType}}
# 			<p class="nds_dialog_text">{{content.title}}</p>
# 			{{/isTextType}}
# 			{{#isTitleType}}
# 			<strong class="nds_dialog_title">
# 				<span class="nds_dialog_title_ellipsis">{{content.headTitle}}</span>
# 				{{content.title}}
# 			</strong>
# 			<p class="nds_dialog_description">{{content.description}}</p>
# 			{{/isTitleType}}
# 		</div>
# 		<div class="nds_dialog_button_area">
# 			<div class="nds_button_main_action as_layout_5_5">
# 				{{#isCancel}}
# 				<button type="button" class="nds_button_wide _MODAL_CANCEL"{{#content.clk.cancelClk}} data-clk="{{content.clk.cancelClk}}"{{/content.clk.cancelClk}}>
# 				{{content.cancelMessage}}
# 				</button>
# 				{{/isCancel}}
# 				<button type="button" class="nds_button_wide as_primary _MODAL_CONFIRM"{{#content.clk.confirmClk}} data-clk="{{content.clk.confirmClk}}"{{/content.clk.confirmClk}}>
# 				{{content.confirmMessage}}
# 				</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div id="_MODAL_TOAST" style="display: none;"></div>
# <script class="_MODAL_TOAST_TEMPLATE" type="x-tmpl-mustache">
# <div class="nds_popover_toast as_center">
# 	<div class="nds_toast_text_area">
# 		<div class="nds_toast_text_area"><span class="nds_toast_ellipsis_text"><strong>{{toastTitle}}</strong></span> {{toastMessage}}</div>
# 	</div>
# </div>
# </script>
# <div class="ticker" id="_TICKER_LAYER_FOR_NOTIFICATION" style="display: none;"></div>
# <script class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script crossorigin="anonymous" onerror="neloSender.sendErrorToNelo('스크립트 로딩 에러 : ' + this.src);" src="https://static-nnews.pstatic.net/js/min/20250403b/library.min.js"></script>
# <script crossorigin="anonymous" onerror="neloSender.sendErrorToNelo('스크립트 로딩 에러 : ' + this.src);" src="https://static-nnews.pstatic.net/js/min/20250403b/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {};
# 		var redirectSection = {"id":"105","name":"IT"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports || service.newsType) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		var issueComponentId = $("._ISSUE_ARTICLE_INFO").attr("data-component-id");
# 		ntmOption["dimension8"] = issueComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)|(www\.naver\.com)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false && $("#contents").length > 0) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("onpagehide" in window ? "pagehide" : "beforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onpagehide" in window ? "onpagehide" : "onbeforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var onUnloadEventName = "onpagehide" in window ? "onpagehide" : "onbeforeunload";
# 				var fnOnUnload = window[onUnloadEventName];
# 				window[onUnloadEventName] = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# </div>
# <script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				window.ntm = window.ntm || [];
#
# 				var pageviewInfo = {
# 					event: "nLogPageViewService",
# 					nlogEvt: {
# 						page_layout: window.layoutName
# 					}
# 				};
#
# 				pageviewInfo.nLogPageviewSti = "news";
#
# 				window.ntm.push(pageviewInfo);
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": "섹션홈"
# 					},
# 					"extraInfo": {
# 						"sectionId": "105"
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
#
# 				setTimeout(function() {
# 					$("._OPACITY_FADE_TO").fadeTo(50, 1);
# 				}, 3000);
# 			});
# 		</script>
# </body>
# </html>
#
# 82
# <class 'bs4.element.ResultSet'>
# https://n.news.naver.com/mnews/article/016/0002454308 “전국민에 맞는 AI 5000만개 보급할 것”…뤼튼, ‘생활형 AI’ 시대 연다
# https://n.news.naver.com/mnews/article/comment/016/0002454308
# https://n.news.naver.com/mnews/article/001/0015317061 스팸문자 사전 차단 '엑스레이 서비스' 9일 시범 도입
# https://n.news.naver.com/mnews/article/comment/001/0015317061
# https://n.news.naver.com/mnews/article/008/0005177334 금융과 통신의 결합…기업은행, SKT와 AI로 보이스피싱 막는다
# https://n.news.naver.com/mnews/article/comment/008/0005177334
# https://n.news.naver.com/mnews/article/001/0015316436 신제품 갤럭시 S25 효과에…삼성전자 MX 1분기 실적 개선
# https://n.news.naver.com/mnews/article/comment/001/0015316436
# https://n.news.naver.com/mnews/article/018/0005982179 신세계I&C, AI 무인매장 솔루션 출시…"리테일테크 사업 확대"
# https://n.news.naver.com/mnews/article/comment/018/0005982179
# https://n.news.naver.com/mnews/article/584/0000031788 '왕좌의 게임' 늑대 부활…1만2500년전 멸종 '다이어울프' 복원
# https://n.news.naver.com/mnews/article/comment/584/0000031788
# https://n.news.naver.com/mnews/article/092/0002369853 뉴엔AI, 英 FT가 뽑은 고성장 '500대 기업' 등극…IPO로 성장 정점 찍나
# https://n.news.naver.com/mnews/article/comment/092/0002369853
# https://n.news.naver.com/mnews/article/001/0015318051 [마켓톺] 관세전쟁에 빛바랜 삼성전자의 호실적…반등의 조건은
# https://n.news.naver.com/mnews/article/comment/001/0015318051
# https://n.news.naver.com/mnews/article/028/0002739882 한국계 우주비행사 태운 러 우주선, 우주정거장 향해 발사
# https://n.news.naver.com/mnews/article/comment/028/0002739882
# https://n.news.naver.com/mnews/article/030/0003301426 LG이노텍, 반도체 유리기판 투자 개시…구미에 시생산 라인 구축
# https://n.news.naver.com/mnews/article/comment/030/0003301426
# https://n.news.naver.com/mnews/article/022/0004026009 자라서 우주비행사 된 韓 이민자 가정 소년…미래 위한 ISS 임무 수행한다
# https://n.news.naver.com/mnews/article/comment/022/0004026009
# https://n.news.naver.com/mnews/article/082/0001320209 “쪼개고 또 쪼개고”… 돈만 좇는 GC녹십자, 주가 추락에도 주주는 없다
# https://n.news.naver.com/mnews/article/comment/082/0001320209
# https://n.news.naver.com/mnews/article/011/0004471627 [영상] '인간 태운 늑대 로봇 질주'…日 차세대 이동수단 '콜레오' 화제
# https://n.news.naver.com/mnews/article/comment/011/0004471627
# https://n.news.naver.com/mnews/article/421/0008180853 뤼튼 "쓸수록 돈버는 무료 AI모델 지향…편의점 등 30여곳 제휴"
# https://n.news.naver.com/mnews/article/comment/421/0008180853
# https://n.news.naver.com/mnews/article/421/0008180849 갤S26 놓고 엇갈리는 전망…"카메라·S펜 큰 변화 없을 것"
# https://n.news.naver.com/mnews/article/comment/421/0008180849
# https://n.news.naver.com/mnews/article/092/0002369845 "중고거래, 피해는 사용자 몫"…개인 보안 솔루션 갖춰야
# https://n.news.naver.com/mnews/article/comment/092/0002369845
# https://n.news.naver.com/mnews/article/030/0003301410 [이슈플러스]1분기 효자는 단연 '갤S25'…4년 만에 4조원 이익 돌파
# https://n.news.naver.com/mnews/article/comment/030/0003301410
# https://n.news.naver.com/mnews/article/030/0003301404 [이슈플러스]삼성전자 1분기 메모리 실적 '선방'
# https://n.news.naver.com/mnews/article/comment/030/0003301404
# https://n.news.naver.com/mnews/article/092/0002369838 소액주주 눈높이 맞춘다…한화에어로, 유증 3.6조→2.3조 축소
# https://n.news.naver.com/mnews/article/comment/092/0002369838
# https://n.news.naver.com/mnews/article/421/0008180782 의협 "작년 2월 전으로 돌아가야"…정부·국회에 대화 요구(종합)
# https://n.news.naver.com/mnews/article/comment/421/0008180782
# https://n.news.naver.com/mnews/article/092/0002369836 한화오션, 차세대 드릴십 인도…심해 시추 본격 진출
# https://n.news.naver.com/mnews/article/comment/092/0002369836
# https://n.news.naver.com/mnews/article/018/0005982544 “보여주면 알아서 설명” 삼성, 갤럭시 S25에 ‘실시간 비주얼 AI’ 도입
# https://n.news.naver.com/mnews/article/comment/018/0005982544
# https://n.news.naver.com/mnews/article/008/0005177554 "5G 투자회수도 멀었는데"…글로벌 통신업계 '6G' 회의론
# https://n.news.naver.com/mnews/article/comment/008/0005177554
# https://n.news.naver.com/mnews/article/014/0005332970 삼성 1분기 실적 효자는 '갤S25'…2Q '슬림' 판매량 관건
# https://n.news.naver.com/mnews/article/comment/014/0005332970
# https://n.news.naver.com/mnews/article/648/0000035139 영화 'HER' 속 사만사처럼…뤼튼의 '1인 1AI' 전략
# https://n.news.naver.com/mnews/article/comment/648/0000035139
# https://n.news.naver.com/mnews/article/009/0005472812 메타, AI 모델 라마4 성능 조작 논란
# https://n.news.naver.com/mnews/article/comment/009/0005472812
# https://n.news.naver.com/mnews/article/092/0002369831 [현장] "AI, 이제 도구가 아닌 친구"…뤼튼, '1인 1AI' 시대 연다
# https://n.news.naver.com/mnews/article/comment/092/0002369831
# https://n.news.naver.com/mnews/article/366/0001067657 폐암 치료 새 길 찾았다…면역 항암제 방해하는 물질 발견
# https://n.news.naver.com/mnews/article/comment/366/0001067657
# https://n.news.naver.com/mnews/article/029/0002946712 의협 “내년 정원 확정해달라…교육 불가능땐 모집인원 줄여야”
# https://n.news.naver.com/mnews/article/comment/029/0002946712
# https://n.news.naver.com/mnews/article/018/0005982502 “자문인줄 알았는데” 리멤버, 전직 직원에 내부정보 요구 논란
# https://n.news.naver.com/mnews/article/comment/018/0005982502
# https://n.news.naver.com/mnews/article/092/0002369827 리플 "전 세계 금융 시장, 실물자산 토큰화 중심으로 근본 변화"
# https://n.news.naver.com/mnews/article/comment/092/0002369827
# https://n.news.naver.com/mnews/article/366/0001067652 당뇨·비만 치료제가 치매 위험 33~43% 낮춘다
# https://n.news.naver.com/mnews/article/comment/366/0001067652
# https://n.news.naver.com/mnews/article/366/0001067651 과기정통부·KISA, 스팸문자 사전 차단 '엑스레이 서비스' 시범 도입
# https://n.news.naver.com/mnews/article/comment/366/0001067651
# https://n.news.naver.com/mnews/article/421/0008180569 에이비엘바이오, '4조 기술이전' 후 첫 공식석상…로드맵 밝힌다
# https://n.news.naver.com/mnews/article/comment/421/0008180569
# https://n.news.naver.com/mnews/article/023/0003898288 한국계 NASA 우주인 조니 김 태운 러 우주선, ISS로 발사
# https://n.news.naver.com/mnews/article/comment/023/0003898288
# https://n.news.naver.com/mnews/article/030/0003301377 “韓 AI 선진국 위해 'AI기술'보다 데이터 확보가 필요”
# https://n.news.naver.com/mnews/article/comment/030/0003301377
# https://n.news.naver.com/mnews/article/092/0002369826 ISMS-P 인증 뭐기에…의무도 아닌데, 하겠단 금융사
# https://n.news.naver.com/mnews/article/comment/092/0002369826
# https://n.news.naver.com/mnews/article/421/0008180565 "의료계 제안 논의하자"…의협, 정부·국회에 '대화의 장' 요구
# https://n.news.naver.com/mnews/article/comment/421/0008180565
# https://n.news.naver.com/mnews/article/014/0005332936 질병청-녹십자 개발 '탄저백신' 품목허가 "백신주권 확립"
# https://n.news.naver.com/mnews/article/comment/014/0005332936
# https://n.news.naver.com/mnews/article/081/0003531724 항암제 피하는 암세포 꼼수 발견…악성 폐암도 잡는다
# https://n.news.naver.com/mnews/article/comment/081/0003531724
# https://n.news.naver.com/mnews/article/421/0008180537 뤼튼 "무료전략으로 생활형 AI 시대 열 것…올해 천만 MAU 목표"
# https://n.news.naver.com/mnews/article/comment/421/0008180537

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':''
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]

for img_url in img_urls:
    pass
    # requests 의 get(url, headers) 함수 호출하기 
        
        # binary 응답 데이터 가져오기
        
        # url에서 파일명만 추출하기
        
        # binday data를 file에 write하기
# Out:
# 200
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg(299,319 bytes)
# 200
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg(163,333 bytes)
# 200
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg(182,530 bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
# Out:
# 200

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청
# Out:
# Error Code: 403

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': '',
    'X-Naver-Client-Secret': '',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'


# requests get(url, params, headers) 요청 

# json() 함수로 응답 결과 가져오오기
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# 'data/nhnblog.txt' 파일 생성하기
